# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("survey.csv")

# %%
df.head()
# Out:
#          Timestamp  How old are you? Which of LGBTQIA+ category are you in?  \
# 0  6/21/2021 19:38                20                                    Gay
# 1  6/21/2021 19:41                20                              Gay,Queer
# 2  6/21/2021 19:52                30                    Gay,People of Color
# 3  6/21/2021 20:25                30              Gay,Queer,People of Color
# 4  6/21/2021 21:27                20         Bisexual,Queer,People of Color
#
#   Which industry are you currently working in?  \
# 0                                   Technology
# 1                                   Technology
# 2                                   Technology
# 3                                   Technology
# 4                                      Fitness
#
#   In which state are you located?  What is your salary range?  \
# 0                      Washington                          90
# 1                      California                          50
# 2                      California                         100
# 3                      California                          70
# 4                        New York                          60
#
#   What types of job are you working?  \
# 0                          Full-time
# 1                             Intern
# 2                          Full-time
# 3                            Student
# 4                           Contract
#
#   Have you ever experience discrimination due to your race, sexual orientation or gender identity?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   If yes, where did you experience discrimination due to your race, sexisual orientation or gender identity?  \
# 0                                      Not workplace
# 1                                      In workplaces
# 2                                      In workplaces
# 3                                      In workplaces
# 4                                      Not workplace
#
#   Which have you done in order to avoid experiencing discrimination because of your race, sexual orientation or gender identity?  \
# 0                        Hid a personal relationship
# 1                        Hid a personal relationship
# 2                        Hid a personal relationship
# 3                        Hid a personal relationship
# 4                                            Did Not
#
#   Would you be interested in a follow-up interview to learn more about your experiences?  If yes, provide contact information in the next question.  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   Please write your contact information. moved
# 0              robin.paul.dean@gmail.com    no
# 1    zipprobertt@gmail.com, 650-208-7426   yes
# 2           John Huan Vu / j.vu@live.com   yes
# 3               Tomomitsukioka@gmail.com    no
# 4                                    NaN   yes

# %%
df.columns = ['date', 'age', 'identity', 'industry', 'state', 'salary', 'statues', 'discriminated', 'location', 'solution','follow', 'contact', 'moved']

# %%
df.head()
# Out:
#               date  age                        identity    industry  \
# 0  6/21/2021 19:38   20                             Gay  Technology
# 1  6/21/2021 19:41   20                       Gay,Queer  Technology
# 2  6/21/2021 19:52   30             Gay,People of Color  Technology
# 3  6/21/2021 20:25   30       Gay,Queer,People of Color  Technology
# 4  6/21/2021 21:27   20  Bisexual,Queer,People of Color     Fitness
#
#         state  salary    statues discriminated       location  \
# 0  Washington      90  Full-time            No  Not workplace
# 1  California      50     Intern           Yes  In workplaces
# 2  California     100  Full-time           Yes  In workplaces
# 3  California      70    Student           Yes  In workplaces
# 4    New York      60   Contract           Yes  Not workplace
#
#                       solution follow                              contact  \
# 0  Hid a personal relationship    Yes            robin.paul.dean@gmail.com
# 1  Hid a personal relationship    Yes  zipprobertt@gmail.com, 650-208-7426
# 2  Hid a personal relationship    Yes         John Huan Vu / j.vu@live.com
# 3  Hid a personal relationship    Yes             Tomomitsukioka@gmail.com
# 4                      Did Not     No                                  NaN
#
#   moved
# 0    no
# 1   yes
# 2   yes
# 3    no
# 4   yes

# %%
df['identity'] = df['identity'].str.split(',')

# %%
# convert list of pd.Series then stack it
df_id = (df
 .set_index(['date','age','industry','state','salary', 'statues', 'discriminated', 'location', 'solution','follow', 'contact','moved'])['identity']
# 22  6/22/2021 18:38   40                               [Bisexual, Queer]
# 23  6/22/2021 20:52   20                                    [Non-binary]
# 24   6/23/2021 7:12   20                     [Bisexual, People of Color]
# 25  6/23/2021 11:27   40                          [Gay, People of Color]
#
#                     industry         state  salary               statues  \
# 0                 Technology    Washington      90             Full-time
# 1                 Technology    California      50                Intern
# 2                 Technology    California     100             Full-time
# 3                 Technology    California      70               Student
# 4                    Fitness      New York      60              Contract
# 5                     Energy         Texas     100             Full-time
# 6                 Technology    Washington     100             Full-time
# 7                 Technology      Colorado      80             Full-time
# 8                  Education    California       0             Full-time
# 9                 Technology    California      50            Unemployed
# 10                     Media    California       0             Full-time
# 11             Data Analyst        Florida      50           Unemployed
# 12                  Textiles      New York     100             Full-time
# 13                     Media      New York     100             Full-time
# 14                Technology      New York     100             Full-time
# 15                Technology  Pennsylvania      50               student
# 16                Technology      Virginia      90             Full-time
# 17  tech-adjacent non-profit    California      90             Full-time
# 18                Technology      New York     100              Contract
# 19                 nonprofit    California      70             Full-time
# 20                Healthcare    California      50              Contract
# 21                   Student        Nevada      50  Student, unemployed
# 22            Manufacturing       New York     100             Full-time
# 23                     Music      Virginia       0             Part-time
# 24                Technology    New Jersey      60              Contract
# 25                     Media      New York       0             Full-time
#
#    discriminated       location                     solution moved
# 0             No  Not workplace  Hid a personal relationship    no
# 1            Yes  In workplaces  Hid a personal relationship   yes
# 2            Yes  In workplaces  Hid a personal relationship   yes
# 3            Yes  In workplaces  Hid a personal relationship    no
# 4            Yes  Not workplace                      Did Not   yes
# 5            Yes  In workplaces  Hid a personal relationship   yes
# 6            Yes  In workplaces  Hid a personal relationship   yes
# 7            Yes  In workplaces                      Did Not   yes
# 8            Yes  In workplaces  Hid a personal relationship   yes
# 9            Yes  Not workplace  Hid a personal relationship    no
# 10           Yes  Not workplace                      Did Not    no
# 11           Yes  In workplaces                      Did Not   yes
# 12           Yes  In workplaces  Hid a personal relationship   yes
# 13            No  Not workplace                      Did Not   yes
# 14           Yes  In workplaces  Hid a personal relationship   yes
# 15           Yes  In workplaces  Hid a personal relationship   yes
# 16           Yes  In workplaces  Hid a personal relationship    no
# 17           Yes  In workplaces                      Did Not   yes
# 18           Yes  Not workplace  Hid a personal relationship   yes
# 19           Yes  In workplaces                      Did Not    no
# 20           Yes  In workplaces  Hid a personal relationship    no
# 21           Yes  Not workplace  Hid a personal relationship   yes
# 22           Yes  In workplaces  Hid a personal relationship   yes
# 23           Yes  Not workplace  Hid a personal relationship   yes
# 24           Yes  In workplaces  Hid a personal relationship    no
# 25            No  Not workplace                      Did Not   yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           26 non-null     object
#  1   age            26 non-null     int64
#  2   identity       26 non-null     object
#  3   industry       26 non-null     object
#  4   state          26 non-null     object
#  5   salary         26 non-null     int64
#  6   statues        26 non-null     object
#  7   discriminated  26 non-null     object
#  8   location       26 non-null     object
#  9   solution       26 non-null     object
#  10  moved          26 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 2.4+ KB

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=df, x = df.discriminated.value_counts().index, y=df.discriminated.value_counts(), palette= 'crest', ci=None)

plt.xlabel("Discriminated Against?", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Discrimination Ratios", fontsize=32)
plt.tight_layout
plt.show()

# %%
desc = df[df.discriminated.str.contains("Yes")]
desc_count = desc.discriminated.count()
total = df.discriminated.count()

ratio = (desc_count / total) * 100

print(ratio,"%")
# Out:
# 88.46153846153845 %

# %%
df_1 = df[~df.discriminated.str.contains("No")]

# %%
df_id_2 = df_id[~df_id.discriminated.str.contains("No")]

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=df_id_2, x = df_id_2.identity.value_counts().index, y=df_id_2.identity.value_counts(), palette= 'crest', ci=None)
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha='right', fontsize=14)

plt.xlabel("Identity", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Those Discriminated Against Identfiy As:", fontsize=32)
plt.tight_layout
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=df_1, x = df.location.value_counts().index, y=df.location.value_counts(), palette= 'crest', ci=None)
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha='right', fontsize=14)

plt.xlabel("Yes or NO", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Those Discriminated in the Workplace:", fontsize=32)
plt.tight_layout
plt.show()

# %%
wp_df = df_1[~df_1.location.str.contains("Not workplace")]

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=wp_df, x = wp_df.age.value_counts().index, y=wp_df.age.value_counts(), palette= 'crest')
g.set_xticklabels(['20s', '30s', '40s', '50s'], fontsize=14)

plt.xlabel("Ages", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Those Discriminated in the Workplace by Age", fontsize=32)
plt.tight_layout
plt.show()

# %%
df_sal = df_1[df_1['salary'] != 0]

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=df_sal, x = df_sal.salary.value_counts().index, y=df_sal.salary.value_counts(), palette= 'BuGn')
g.set_xticklabels(['<60k', '61-70k', '71-80k', '81-90k', '91-100k', '101k<'], fontsize=14)

plt.xlabel("Salaries", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Distribution of Salaries", fontsize=32)
plt.tight_layout
plt.show()

# %%
wrk = df_1[df_1.location.str.contains("In workplaces")]
wrk_count = wrk.location.count()
total_wrk = df_1.location.count()

wrk_ratio = (wrk_count / total_wrk) * 100

print(wrk_ratio,"%")
# Out:
# 73.91304347826086 %

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=df_1, x = df.state.value_counts().index, y=df.state.value_counts(), palette= 'inferno_r')
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha='right', fontsize=14)

plt.xlabel("State", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Where people are reporting Discrimination", fontsize=32)
plt.tight_layout
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,8))
g = sns.barplot(data=df_1, x = df.moved.value_counts().index, y=df.moved.value_counts(), palette= 'rocket', ci=None)
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha='right', fontsize=20)

plt.xlabel("Yes or No", fontsize=20)
plt.ylabel("Amount", fontsize=20)
plt.title("Amount of People Who Moved to a Different City or Away from Family", fontsize=32)
plt.tight_layout
plt.show()

# %%
move = df_1[df_1.moved.str.contains("yes")]
move_count = move.moved.count()
total_move = df_1.moved.count()

move_ratio = (move_count / total_move) * 100

print(move_ratio,"%")
# Out:
# 69.56521739130434 %

# %%
import pandas as pd

data = {'Situation':  ['Experienced Discrimination', 'Of those affected, amount in the workplace.','Of those affected, amount that moved from family or to a different city.'],
        'Percentage Affected': [ratio, wrk_ratio, move_ratio]
        }

sad_data = pd.DataFrame (data, columns = ['Situation','Percentage Affected'])

print (sad_data)
# Out:
#                                            Situation  Percentage Affected
# 0                         Experienced Discrimination            88.461538
# 1        Of those affected, amount in the workplace.            73.913043
# 2  Of those affected, amount that moved from fami...            69.565217
